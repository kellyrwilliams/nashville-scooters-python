# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
may_location = pd.read_pickle("../data/may.pkl")

# %%
june_location = pd.read_pickle("../data/june.pkl")

# %%
july_location = pd.read_pickle("../data/july.pkl")

# %%
may_trip = pd.read_csv('../data/may_trip.csv')

# %%
june_trip = pd.read_csv('../data/june_trip.csv')

# %%
july_trip = pd.read_csv('../data/july_trip.csv')

# %%
may_location.head()
# Out:
#               pubdatetime   latitude  longitude        sumdid  chargelevel  \
# 0 2019-05-01 00:01:41.247  36.136822 -86.799877  PoweredLIRL1         93.0
# 1 2019-05-01 00:01:41.247  36.191252 -86.772945  PoweredXWRWC         35.0
# 2 2019-05-01 00:01:41.247  36.144752 -86.806293  PoweredMEJEH         90.0
# 3 2019-05-01 00:01:41.247  36.162056 -86.774688  Powered1A7TC         88.0
# 4 2019-05-01 00:01:41.247  36.150973 -86.783109  Powered2TYEF         98.0
#
#    companyname
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
may_trip.tail()
# Out:
#                       pubTimeStamp companyName tripRecordNum  \
# 224964  2019-06-01 23:50:42.373000        Lime       LIM5241
# 224965  2019-06-01 23:50:42.397000        Lime       LIM5285
# 224966  2019-06-01 23:50:42.480000        Lime       LIM5413
# 224967  2019-06-01 23:50:42.480000        Lime       LIM5412
# 224968  2019-06-13 05:17:41.630000        SPIN        SPI146
#
#                       sumdID  tripDuration  tripDistance            startDate  \
# 224964  PoweredJ6OI7QJIK4NO2     62.316667       0.00000  2019-05-31 00:00:00
# 224965  PoweredQDVYGLDL6ZQDU     22.383333    9337.15680  2019-05-31 00:00:00
# 224966  PoweredH5HCTZB5WVABT     40.200000   20951.18880  2019-05-31 00:00:00
# 224967  PoweredFXC5KHVLI3T7C     41.033333   21049.61280  2019-05-31 00:00:00
# 224968        Powered5750098  36206.000000   21551.83796  2019-05-19 00:00:00
#
#        startTime              endDate   endTime  startLatitude  \
# ...

# %%
may_trip.value_counts('companyName')
# Out:
# companyName
# Lime             102569
# Lyft              54271
# Bird              53496
# SPIN               8471
# Bolt Mobility      4912
# Gotcha              650
# JUMP                600
# dtype: int64

# %%
may_trip.plot('companyName','tripDuration')
# Out:
# <AxesSubplot:xlabel='companyName'>

# %%
may_trip.describe()
# Out:
#         tripDuration  tripDistance  startLatitude  startLongitude  \
# count  224969.000000  2.249690e+05  224969.000000   224969.000000
# mean       42.701454  4.068519e+03      36.154927      -86.784143
# std       270.980984  2.605852e+04       0.013479        0.013873
# min         0.000000 -2.758530e+06      36.037283      -86.918008
# 25%         5.050000  3.380232e+02      36.149865      -86.791500
# 50%        10.116667  1.640420e+03      36.156793      -86.781410
# 75%        20.000000  5.488845e+03      36.162700      -86.776201
# max     36206.000000  7.580026e+06      36.293024      -86.600733
#
#          endLatitude   endLongitude
# count  224969.000000  224969.000000
# mean       36.155499     -86.784114
# std         0.020068       0.070626
# min        32.775953    -117.076117
# 25%        36.150100     -86.791700
# 50%        36.157247     -86.781394
# 75%        36.162730     -86.776193
# max        39.997793     -77.021907

# %%
june_trip.describe()
# Out:
#         tripDuration  tripDistance  startLatitude  startLongitude  \
# count  205627.000000  2.056270e+05  205627.000000   205627.000000
# mean       81.454936  5.254084e+03      36.156242      -86.784564
# std       431.513564  4.370924e+04       0.012074        0.013882
# min        -8.003717 -5.157480e+05      36.042892      -86.917893
# 25%         5.000000  9.481628e+02      36.150659      -86.792074
# 50%        10.000000  3.323491e+03      36.157100      -86.782000
# 75%        20.000000  6.952015e+03      36.163040      -86.776493
# max     11836.000000  1.848950e+07      36.300029      -86.602127
#
#          endLatitude   endLongitude
# count  205627.000000  205627.000000
# mean       36.156277     -86.784505
# std         0.169490       0.608159
# min       -36.850405    -122.428964
# 25%        36.150858     -86.792100
# 50%        36.157572     -86.781700
# 75%        36.163067     -86.776380
# max        47.613101     174.764886

# %%
july_trip.describe()
# Out:
#         tripDuration  tripDistance  startLatitude  startLongitude  \
# count  134926.000000  1.349260e+05  134926.000000   134926.000000
# mean       97.097264  5.333994e+03      36.156738      -86.785144
# std      1722.548585  1.406051e+05       0.010914        0.013987
# min       -19.358267 -2.032480e+07      35.853200      -86.890850
# 25%         5.000000  3.280840e+02      36.150938      -86.793142
# 50%        10.148442  2.956037e+03      36.157200      -86.782100
# 75%        21.250550  6.916011e+03      36.162900      -86.776691
# max    512619.000000  3.188448e+07      36.299569      -86.366200
#
#          endLatitude   endLongitude
# count  134926.000000  134926.000000
# mean       36.156680     -86.785514
# std         0.118461       0.396499
# min         0.000000    -122.673729
# 25%        36.151014     -86.792596
# 50%        36.157680     -86.781523
# 75%        36.162800     -86.776546
# max        51.045409       0.000000

# %%
lime_may_trip = may_trip.loc[may_trip['companyName'] == 'Lime']
lime_may_trip.head()
# Out:
#                     pubTimeStamp companyName tripRecordNum  \
# 2217  2019-05-02 00:18:00.487000        Lime          LIM3
# 2218  2019-05-02 00:18:00.487000        Lime          LIM2
# 2219  2019-05-02 00:18:00.487000        Lime          LIM1
# 2220  2019-05-02 00:18:00.490000        Lime          LIM6
# 2221  2019-05-02 00:18:00.490000        Lime          LIM5
#
#                     sumdID  tripDuration  tripDistance            startDate  \
# 2217  PoweredTB6JVKPTKJCQL      4.233333      259.0800  2019-05-01 00:00:00
# 2218  PoweredOJFHQP5R57XW6      2.916667        0.0000  2019-05-01 00:00:00
# 2219  PoweredFAIGWPKA27PCZ      5.016667       76.8096  2019-05-01 00:00:00
# 2220  PoweredGP3STF2M7IY5V     10.700000      280.7208  2019-05-01 00:00:00
# 2221  PoweredWADT2R7GCJUNZ      1.900000      196.5960  2019-05-01 00:00:00
#
#      startTime              endDate   endTime  startLatitude  startLongitude  \
# ...

# %%
may_trip.sort_values('tripDuration', ascending=False)
# Out:
#                       pubTimeStamp    companyName tripRecordNum  \
# 224968  2019-06-13 05:17:41.630000           SPIN        SPI146
# 168630  2019-05-25 18:16:36.020000           SPIN         SPI17
# 206479         2019-05-28 22:38:44  Bolt Mobility      BOL00258
# 222979         2019-05-31 21:11:22  Bolt Mobility      BOL00445
# 203607         2019-05-28 06:23:09  Bolt Mobility      BOL00149
# ...                            ...            ...           ...
# 129842  2019-05-19 22:37:31.517000           Bird       BRD3043
# 23554   2019-05-04 20:45:26.980000           Bird       BRD3437
# 129840  2019-05-19 22:37:31.517000           Bird       BRD3044
# 129839  2019-05-19 22:37:31.517000           Bird       BRD3045
# 182628  2019-05-26 17:10:03.400000           Bird       BRD1703
#
#                                               sumdID  tripDuration  \
# 224968                                Powered5750098       36206.0
# ...

# %%
may_trip.tripDuration.dtype
# Out:
# dtype('float64')

# %%
may_trip_facetgrid = sns.FacetGrid(may_trip, hue='companyName', height=4)
may_trip_facetgrid.map(plt.plot, 'companyName', 'tripDistance', marker='o')
may_trip_facetgrid.add_legend()

# %%
june_trip_facetgrid = sns.FacetGrid(june_trip, hue='companyName', height=4)
june_trip_facetgrid.map(plt.plot, 'companyName', 'tripDistance', marker='o')
june_trip_facetgrid.add_legend()

# %%
## july_trip_facetgrid = sns.FacetGrid(july_trip, col='companyName', hue='companyName', height=3)
july_trip_facetgrid.map(plt.plot, 'companyName', 'tripDistance', marker='o')
july_trip_facetgrid.add_legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-30cba982ff22> in <module>
#       1 ## july_trip_facetgrid = sns.FacetGrid(july_trip, col='companyName', hue='companyName', height=3)
# ----> 2 july_trip_facetgrid.map(plt.plot, 'companyName', 'tripDistance', marker='o')
#       3 july_trip_facetgrid.add_legend()
#
# NameError: name 'july_trip_facetgrid' is not defined

# %%
may_trip['distanceMiles'] = may_trip.tripDistance/5280

# %%
may_trip.head()

# %%
plt.scatter('companyName','distanceMiles', data = may_trip)

# %%
plt.scatter('companyName','tripDistance', data = june_trip)

# %%
plt.scatter('companyName','tripDistance', data = july_trip)

# %%
may_trip.value_counts('sumdID').head(20)
# Out:
# sumdID
# PoweredUNKNOWN                                 2166
# Poweredb671ffe4-2bca-5880-98ec-d36f65aa11a2     600
# PoweredWVIAXNCVDNOXP                            338
# PoweredR3QXO6TL2HIAB                            291
# PoweredRJ7YYJTHAR5N3                            274
# PoweredEGRN7CFK6Q6K2                            261
# PoweredDJQATZBXPBUAE                            254
# PoweredLNAVSI3QKRPVH                            225
# Powered75MFAMZCCD3QJ                            222
# PoweredKCXMXKUIP3Z4E                            221
# PoweredGVLQSJDAXWVPX                            200
# Powered7F7SGZH42ZGS7                            196
# Powered34ZSQ3V4KEPAS                            195
# PoweredRRC5FV6DYYHBL                            193
# Powered4FCVKYQ3DTH7H                            191
# PoweredLABZO3C5YHDP4                            186
# Powered4WOKR5XFN26KV                            185
# Powered3XINKE5ALW66Z                            184
# ...
